# %%
import scrapy
import pandas as pd
import sys
import os
import seaborn as sns
import matplotlib.pyplot as plt
from pymongo import MongoClient
import json
import datetime
import numpy as np

# %%
# -*- coding: utf-8 -*-
import scrapy
import os
import datetime
import pandas as pd

class MyspiderbotSpider(scrapy.Spider):
    def readAndInsert(self,fileLocation):
        excelFile=pd.ExcelFile(fileLocation)
        
    name = 'mySpiderBot'
    allowed_domains = ['http://mca.gov.in']
    start_urls = ['http://mca.gov.in/mcafoportal/companiesRegReport.do']
    errorFileName="error.log"
    dataFileName="Company_Registered_in_Last_30days_"+datetime.datetime.now().strftime("%d_%m_%h")+".xlsx"
    dataFileLocation="/home/digiapt/Desktop/mca_gov_in/mca_gov_in/spiders/fetchedFile/"+dataFileName
    def errorback(self,res):
        with open(self.errorFileName,"a") as fp:
            fp.write(datetime.datetime.now().strftime("%d-%m-%h (%H:%M:%S)")+" - "+str(res)+"\r\n")
        print("please check error log file for more information")
    def callback(self,res):
        content=res.body
        with open(self.dataFileLocation,"wb") as fp:
            fp.write(content)
        print("done writing")




    def start_requests(self):
        headers= {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:63.0) Gecko/20100101 Firefox/63.0','Cache-Control': 'max-age=0','referer':'mca.gov.in'}
        for url in self.start_urls:
            yield scrapy.Request(url,headers=headers,errback=self.errorback,callback=self.callback,dont_filter=True)

# %%
# -*- coding: utf-8 -*-
import scrapy
import pandas as pd
import sys
import os
import seaborn as sns
import matplotlib.pyplot as plt
from pymongo import MongoClient
import json
import datetime
import numpy as np

class MyspiderbotSpider(scrapy.Spider):
        
    name = 'mySpiderBot'
    allowed_domains = ['http://mca.gov.in']
    start_urls = ['http://mca.gov.in/mcafoportal/companiesRegReport.do']
    errorFileName="error.log"
    dataFileName="Company_Registered_in_Last_30days_"+datetime.datetime.now().strftime("%d_%m_%h")+".xlsx"
    dataFileLocation="/home/digiapt/Desktop/mca_gov_in/mca_gov_in/spiders/fetchedFile/"+dataFileName
    successFileName="success.log"
    
    schemaColumns={
        "COMPANY NAME":"name",
        "LIMITED LIABILITY PARTNERSHIP NAME":"name",
        "FOREIGN LIMITED LIABILITY PARTNERSHIP":"name",
        "CIN":"identityNumber",
        "FCRN":"identityNumber",
        "LLPIN":"identityNumber",
        "FLLPIN":"identityNumber",
        "COUNTRY":"country",
        "COUNTRY OF INCORPORATION":"country",
        "DATE OF INCORPORATION":"dateOfIncorporation",
        "DATE OF REGISTRATION":"dateOfIncorporation",
        "STATE":"state",
        "STATE OF PRINCIPAL PLACE OF BUSINESS IN INDIA":"state",
        "ROC":"ROC",
        "CATEGORY":"category",
        "SUB CATEGORY":"subCategory",
        "CLASS":"class",
        "AUTHORIZED_CAPITAL":"authorizedCapital",
        "PAID CAPITAL":"paidCapital",
        "NUMBER OF PARTNERS":"numberOfPartners",
        "NUMBER OF MEMBERS (Applicable only in case of Co. without share Capital)":"numberOfPartners",
        "NUMBER OF DESIGNATED PARTNERS":"numberOfDesignatedParters",
        "ACTIVITY DESCRIPTION":"activityDiscription",
        "ACTIVITY_DESCRIPTION":"activityDiscription",
        "REGISTERED_OFFICE_ADDRESS":"officeAddressInIndia",
        "FOREIGN COMPANY PRESENT ADDRESS IN INDIA":"officeAddressInIndia",
        "FOREIGN OFFICE ADDRESS":"officeAddressInForeign",
        "TOTAL OBLIGATION OF CONTRIBUTION":"totalObligationOfContribution",
        "TYPE OF OFFICE":"typeOfOffice"}
    schema2sheet={
        "name":0,
        "identityNumber" :0,
        "country":0,
        "dateOfIncorporation":0,
        "state":0,
        "ROC":0,
        "category":0,
        "subCategory":0,
        "class":0,
        "authorizedCapital":0,
        "paidCapital":0,
        "numberOfPartners":0,
        "numberOfDesignatedParters":0,
        "activityDiscription":0,
        "officeAddressInIndia":0,
        "officeAddressInForeign":0,
        "totalObligationOfContribution":0,
        "typeOfOffice":0
        }

    def createDataList(self,df,sheet,dataList,sheetOne,sheetTwo,sheetThree,sheetFour):
        if sheet==sheetOne: #"Indian Companies Registered"
            columns=df.columns.values
            entity={}
            incorporationData={}
            emptyField={}
            registrationData={"registrationData":"null"}
            commonCol={}
            for col in columns:
                commonCol[self.schemaColumns[col]]=0
            for index in range(df.shape[0]):
                tmp={}
                tmp1={}
                tmp2={}
                tmp3={}
                #tmp['isCompany']=True;tmp['isLLP']=False;tmp['isForeign']=False;tmp['isDomestic']=True;tmp['identityLabel']="CIN"
                tmp1['isCompany']=True;tmp1['isLLP']=False;tmp1['isForeign']=False;tmp1['isDomestic']=True;
                tmp1['identityLabel']="CIN"
                tmp1['type']="incorporation"
                row=df.iloc[index]
                for col in columns:
                    if col=="COMPANY NAME" or  col == "ACTIVITY_DESCRIPTION" or col=="ROC" or col=="STATE" or col == "CIN" or col == "DATE OF INCORPORATION" or col == "REGISTERED_OFFICE_ADDRESS" :
                        #tmp[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                        tmp1[self.schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                    elif col == "CATEGORY" or col == "SUB CATEGORY" or col == "CLASS" or col == "AUTHORIZED_CAPITAL" or col == "PAID CAPITAL" or col is "NUMBER OF MEMBERS":
                        tmp2[self.schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
            
                for unInsertedKey in self.schema2sheet.keys():
                    if unInsertedKey not in commonCol:
                        #tmp[unInsertedKey]="null"
                        tmp3[unInsertedKey]="null"
                entity['entity']=tmp1
                incorporationData['incorporationData']=tmp2
                emptyField['emptyField']=tmp3
                tmp={**entity,**incorporationData,**emptyField,**registrationData}
                dataList.append(tmp)
            
            
            
            
            
        
        elif sheet==sheetTwo: #Foreign Companies Registered
            columns=df.columns.values
            commonCol={}
            entity={}
            registrationData={}
            incorporationData={"incorporationData":"null"}
            emptyField={}
            for col in columns:
                commonCol[self.schemaColumns[col]]=0
            for index in range(df.shape[0]):
                tmp={}
                tmp1={}
                tmp2={}
                tmp3={}
                tmp1['isCompany']=True;tmp1['isLLP']=False;tmp1['isForeign']=True;tmp1['isDomestic']=False;
                tmp1['identityLabel']="FCRN"
                tmp1['type']="registration"
                tmp1['type']="India"
                tmp1['vehicle']="company"
                tmp['isCompany']=True;tmp['isLLP']=False;tmp['isForeign']=True;tmp['isDomestic']=False;tmp['identityLabel']="FCRN"
                row=df.iloc[index]
                for col in columns:
                    if col=="COMPANY NAME" or col == "ACTIVITY_DESCRIPTION" or col=="STATE" or col=="ROC" or col == "FCRN" or col == "DATE OF REGISTRATION" or  col =="FOREIGN COMPANY PRESENT ADDRESS IN INDIA" or col == "REGISTERED_OFFICE_ADDRESS" :
                        #tmp[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                        tmp1[self.schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                    elif col == "TYPE OF OFFICE" or col == "COUNTRY OF INCORPORATION" or col == "FOREIGN OFFICE ADDRESS":
                        tmp2[self.schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                
                    #tmp[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                
                
                for unInsertedKey in self.schema2sheet.keys():
                    if unInsertedKey not in commonCol:
                        if unInsertedKey=="COUNTRY":continue
                        #tmp[unInsertedKey]="null"
                        tmp3[unInsertedKey]="null"
                entity['entity']=tmp1
                registrationData['registrationData']=tmp2
                emptyField['emptyField']=tmp3
                tmp={**entity,**registrationData,**incorporationData,**emptyField}
                dataList.append(tmp)
            
        elif sheet==sheetThree: #LLP Registered
            columns=df.columns.values
            commonCol={}
            for col in columns:
                    commonCol[self.schemaColumns[col]]=0
            for index in range(df.shape[0]):
                tmp={}
                tmp['isCompany']=False;tmp['isLLP']=True;tmp['vehicle']="LLP";tmp['isForeign']=False;tmp['isDomestic']=True;tmp['identityLabel']="LLPIN"
                row=df.iloc[index]
                for col in columns:
                    tmp[self.schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                for unInsertedKey in self.schema2sheet.keys():
                    if unInsertedKey not in commonCol:
                        tmp[unInsertedKey]="null"
                dataList.append(tmp)        
        
        elif sheet==sheetFour: #Foreign LLP Registered
            columns=df.columns.values
            commonCol={}
            for col in columns:
                    commonCol[self.schemaColumns[col]]=0
            for index in range(df.shape[0]):
                tmp={}
                tmp['isCompany']=False;tmp['isLLP']=True;tmp['LLP']="company";tmp['isForeign']=True;tmp['isDomestic']=False;tmp['identityLabel']="FLLPIN"
                try:
                    row=df.iloc[index]
                    for col in columns:
                        tmp[self.schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                    for unInsertedKey in self.schema2sheet.keys():
                        if unInsertedKey not in commonCol:
                            tmp[unInsertedKey]="null"
                    dataList.append(tmp)
                except Exception as e:
                    pass
        return dataList
    
    
    
    
    def readAndInsert(self,fileLocation):
        excelFile=pd.ExcelFile(fileLocation)

    def errorback(self,res):
        with open(self.errorFileName,"a") as fp:
            fp.write(datetime.datetime.now().strftime("%d-%m-%h (%H:%M:%S)")+" - "+str(res)+"\r\n")
        print("please check error log file for more information")
        
    def callback(self,res):
        content=res.body
        with open(self.dataFileLocation,"wb") as fp:
            fp.write(content)
        print("done writing")
        dataList=[]
        excelFile=pd.ExcelFile(self.dataFileLocation)
        sheetOne="Indian Companies Registered"
        sheetTwo="Foreign Companies Registered"
        sheetThree="LLP Registered"
        sheetFour="Foreign LLP Registered"
        for sheet in ["Indian Companies Registered","Foreign Companies Registered"]:
            df=pd.read_excel(excelFile,sheet_name=sheet)
            df.columns=df.iloc[0]
            df.drop(0,inplace=True)
            dataList=self.createDataList(df,sheet,dataList,sheetOne,sheetTwo,sheetThree,sheetFour)
        meta={}
        meta["dateCreated"]=datetime.datetime.now().strftime("%d/%m/%y")
        meta["source"]="http://mca.gov.in"
        meta["sourceURL"]="http://mca.gov.in/mcafoportal/companiesRegReport.do"
        dataList.append({"metaData":meta})
        mongoClient=MongoClient()
        db=mongoClient.mcaGovIn
        collection=db.companies
        
        try:
            collection.insert_many(dataList)
            with open(self.successFileName,"a") as fp:
                fp.write(datetime.datetime.now().strftime("%d-%m-%h (%H:%M:%S)")+" - "+" Insertion Successful, Successfully Crawled"+"\r\n")
            print("**********************************Successfully Crawled*******************************************")
        except Exception as e:
            with open(self.errorFileName,"a") as fp:
                fp.write(datetime.datetime.now().strftime("%d-%m-%h (%H:%M:%S)")+" - "+" Insertion Failed: - "+str(e)+"\r\n")
            print("**********************************Insertion Failed, Please check error log for more information*******************************************")
        




    def start_requests(self):
        headers= {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:63.0) Gecko/20100101 Firefox/63.0','Cache-Control': 'max-age=0','referer':'mca.gov.in'}
        for url in self.start_urls:
            yield scrapy.Request(url,headers=headers,errback=self.errorback,callback=self.callback,dont_filter=True)

# %%
excelFile=pd.ExcelFile("./record.xlsx")
sheetOne="Indian Companies Registered"
sheetTwo="Foreign Companies Registered"
sheetThree="LLP Registered"
sheetFour="Foreign LLP Registered"

# %%
df=pd.read_excel(excelFile,sheet_name=sheetTwo)
df.columns=df.iloc[0]
df.drop(0,inplace=True)

# %%
excelFile=pd.ExcelFile("./record.xlsx")
sheetOne="Indian Companies Registered"
sheetTwo="Foreign Companies Registered"
sheetThree="LLP Registered"
sheetFour="Foreign LLP Registered"
schemaColumns={
        "COMPANY NAME":"name",
        "LIMITED LIABILITY PARTNERSHIP NAME":"name",
        "FOREIGN LIMITED LIABILITY PARTNERSHIP":"name",
        "CIN":"identityNumber",
        "FCRN":"identityNumber",
        "LLPIN":"identityNumber",
        "FLLPIN":"identityNumber",
        "COUNTRY":"country",
        "COUNTRY OF INCORPORATION":"country",
        "DATE OF INCORPORATION":"dateOfIncorporation",
        "DATE OF REGISTRATION":"creationDate",
        "STATE":"state",
        "STATE OF PRINCIPAL PLACE OF BUSINESS IN INDIA":"state",
        "ROC":"ROC",
        "CATEGORY":"category",
        "SUB CATEGORY":"subCategory",
        "CLASS":"class",
        "AUTHORIZED_CAPITAL":"authorizedCapital",
        "PAID CAPITAL":"paidCapital",
        "NUMBER OF PARTNERS":"numberOfPartners",
        "NUMBER OF MEMBERS (Applicable only in case of Co. without share Capital)":"numberOfPartners",
        "NUMBER OF DESIGNATED PARTNERS":"numberOfDesignatedParters",
        "ACTIVITY DESCRIPTION":"activityDiscription",
        "ACTIVITY_DESCRIPTION":"activityDiscription",
        "REGISTERED_OFFICE_ADDRESS":"officeAddressInIndia",
        "FOREIGN COMPANY PRESENT ADDRESS IN INDIA":"officeAddressInIndia",
        "FOREIGN OFFICE ADDRESS":"officeAddressInForeign",
        "TOTAL OBLIGATION OF CONTRIBUTION":"totalObligationOfContribution",
        "TYPE OF OFFICE":"typeOfOffice"}
    
schema2sheet={
    "name":0,
    "identityNumber" :0,
    "country":0,
    "dateOfIncorporation":0,
    "state":0,
    "ROC":0,
    "category":0,
    "subCategory":0,
    "class":0,
    "authorizedCapital":0,
    "paidCapital":0,
    "numberOfPartners":0,
    "numberOfDesignatedParters":0,
    "activityDiscription":0,
    "officeAddressInIndia":0,
    "officeAddressInForeign":0,
    "totalObligationOfContribution":0,
    "typeOfOffice":0
}
def createDataList(df,sheet,dataList):
    if sheet == "Indian Companies Registered": #"Indian Companies Registered"
        columns=df.columns.values
        entity={}
        incorporationData={}
        emptyField={}
        registrationData={"registrationData":"null"}
        commonCol={}
        for col in columns:
                commonCol[schemaColumns[col]]=0
        for index in range(df.shape[0]):
            tmp={}
            tmp1={}
            tmp2={}
            tmp3={}
            #tmp['isCompany']=True;tmp['isLLP']=False;tmp['isForeign']=False;tmp['isDomestic']=True;tmp['identityLabel']="CIN"
            tmp1['isCompany']=True;tmp1['isLLP']=False;tmp1['isForeign']=False;tmp1['isDomestic']=True;
            tmp1['identityLabel']="CIN"
            tmp1['type']="incorporation"
            row=df.iloc[index]
            for col in columns:
                if col=="COMPANY NAME" or  col == "ACTIVITY_DESCRIPTION" or col=="ROC" or col=="STATE" or col == "CIN" or col == "DATE OF INCORPORATION" or col == "REGISTERED_OFFICE_ADDRESS" :
                    #tmp[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                    tmp1[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                elif col == "CATEGORY" or col == "SUB CATEGORY" or col == "CLASS" or col == "AUTHORIZED_CAPITAL" or col == "PAID CAPITAL" or col is "NUMBER OF MEMBERS":
                    tmp2[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
            
            entity['entity']=tmp1
            incorporationData['incorporationData']=tmp2
            tmp={**entity,**incorporationData,**registrationData}
            dataList.append(tmp)
        
    elif sheet==sheetTwo: #Foreign Companies Registered
        columns=df.columns.values
        commonCol={}
        entity={}
        registrationData={}
        incorporationData={"incorporationData":"null"}
        emptyField={}
        for col in columns:
                commonCol[schemaColumns[col]]=0
        for index in range(df.shape[0]):
            tmp={}
            tmp1={}
            tmp2={}
            tmp3={}
            tmp1['isCompany']=True;tmp1['isLLP']=False;tmp1['isForeign']=True;tmp1['isDomestic']=False;
            tmp1['identityLabel']="FCRN"
            tmp1['type']="registration"
            tmp1['vehicle']="company"
            tmp['isCompany']=True;tmp['isLLP']=False;tmp['isForeign']=True;tmp['isDomestic']=False;tmp['identityLabel']="FCRN"
            row=df.iloc[index]
            for col in columns:
                if col=="COMPANY NAME" or col == "ACTIVITY_DESCRIPTION" or col=="STATE" or col=="ROC" or col == "FCRN" or col == "DATE OF REGISTRATION" or  col =="FOREIGN COMPANY PRESENT ADDRESS IN INDIA" or col == "REGISTERED_OFFICE_ADDRESS" :
                    #tmp[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                    tmp1[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                elif col == "TYPE OF OFFICE" or col == "COUNTRY OF INCORPORATION" or col == "FOREIGN OFFICE ADDRESS":
                    tmp2[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                
                #tmp[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                
                
            for unInsertedKey in schema2sheet.keys():
                if unInsertedKey not in commonCol:
                    #tmp[unInsertedKey]="null"
                    tmp3[unInsertedKey]="null"
            entity['entity']=tmp1
            registrationData['registrationData']=tmp2
            emptyField['emptyField']=tmp3
            tmp={**entity,**registrationData,**incorporationData,**emptyField}
            dataList.append(tmp)
            
    elif sheet==sheetThree: #LLP Registered
        columns=df.columns.values
        commonCol={}
        for col in columns:
                commonCol[schemaColumns[col]]=0
        for index in range(df.shape[0]):
            tmp['isCompany']=False;tmp['isLLP']=True;tmp['isForeign']=False;tmp['isDomestic']=True;tmp['identityLabel']="LLPIN"
            row=df.iloc[index]
            for col in columns:
                tmp[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
            for unInsertedKey in schema2sheet.keys():
                if unInsertedKey not in commonCol:
                    tmp[unInsertedKey]="null"
            dataList.append(tmp)        
        
    elif sheet==sheetFour: #Foreign LLP Registered
        columns=df.columns.values
        commonCol={}
        for col in columns:
                commonCol[schemaColumns[col]]=0
        for index in range(df.shape[0]):
            tmp={}
            tmp['isCompany']=False;tmp['isLLP']=True;tmp['isForeign']=True;tmp['isDomestic']=False;tmp['identityLabel']="FLLPIN"
            try:
                row=df.iloc[index]
                for col in columns:
                    tmp[schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                for unInsertedKey in schema2sheet.keys():
                    if unInsertedKey not in commonCol:
                        tmp[unInsertedKey]="null"
                dataList.append(tmp)
            except Exception as e:
                pass
    return dataList
            
'''
df=pd.read_excel(excelFile,sheet_name="LLP Registered")
df.columns=df.iloc[0]
df.drop(0,inplace=True)
createDataList(df,sheet) 
'''
dataList=[]

for sheet in ["Indian Companies Registered","Foreign Companies Registered"]:
    df=pd.read_excel(excelFile,sheet_name=sheet)
    df.columns=df.iloc[0]
    df.drop(0,inplace=True)
    dataList=createDataList(df,sheet,dataList)
#df=pd.read_excel(excelFile,sheet_name="Indian Companies Registered")
#df.columns=df.iloc[0]
#df.drop(0,inplace=True)
#dataList=[]
#dataList=createDataList(df.head(),"Indian Companies Registered",dataList)
meta={}
meta["dateCreated"]=datetime.datetime.now().strftime("%d/%m/%y")
meta["source"]="http://mca.gov.in"
meta["sourceURL"]="http://mca.gov.in/mcafoportal/companiesRegReport.do"
dataList.append({"metaData":meta})

# %%
dataList
# Out:
# [{'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100AP2018PTC109756',
#    'name': 'BUBBA AQUA FARM TECH PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-16',
#    'state': 'Andhra Pradesh',
#    'ROC': 'RoC - Hyderabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   10-2, OLD ANDHRA BANK ROAD, D2 CHIRALA CHIRALA Prakasam AP 523165 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100AP2018PTC109775',
#    'name': 'CLARION HEIGHTS INDIA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-20',
#    'state': 'Andhra Pradesh',
#    'ROC': 'RoC - Hyderabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   D.NO.1-164, BRAHMIN STREET, DACHEPALLI VILLAGE, GUNTUR Guntur AP 522414 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100AP2018PTC109823',
#    'name': 'VANAPAMULA SEEDS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-28',
#    'state': 'Andhra Pradesh',
#    'ROC': 'RoC - Hyderabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   D.No.2-2-80, Flat No. 301, 3rd Floor, Tulasi Nilayam,UdyogNagar,SVN Colony ext GUNTUR Guntur AP 522006 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 200000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100AP2018PTC109897',
#    'name': 'GENUINE FARM PRODUCTS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-04',
#    'state': 'Andhra Pradesh',
#    'ROC': 'RoC - Hyderabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   # 2-167,NEAR GOVT HOSPITAL PAIPALYAM VILLEGE ,VASANADU POST KUPPAM MANDAL Chittoor AP 517425 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100AP2018PTC109914',
#    'name': 'AMEYA FROZEN FOODS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-06',
#    'state': 'Andhra Pradesh',
#    'ROC': 'RoC - Hyderabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   80-16-3, Srinivasa Nagar Happy homes, J N Road RAJAMAHENDRAVARAM East Godavari AP 533103 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100AP2018PTC109919',
#    'name': 'NAVYANDHRA FODDER AND FORAGES PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-07',
#    'state': 'Andhra Pradesh',
#    'ROC': 'RoC - Hyderabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   H.NO.1-24, BELLAMKONDAVARI PALEM (V), TALLURU (MD) Prakasam AP 523252 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100AS2018PTC018872',
#    'name': 'AYANANT VENTURES PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-19',
#    'state': 'Assam',
#    'ROC': 'RoC - Shillong',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   3B, Agrim Vista, Block-V, Dharapur GUWAHATI Kamrup AS 781017 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100BR2018PTC039971',
#    'name': 'CHSHMI INTERNET PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-14',
#    'state': 'Bihar',
#    'ROC': 'RoC - Patna',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   C/O SUDARSHAN PRASAD, 165 RAMDHANPUR GABRA, PAR GAYA Gaya BR 823001 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100BR2018PTC039990',
#    'name': 'GIDHESHWAR NATH FARMERS PRODUCER COMPANYLIMITED',
#    'dateOfIncorporation': '2018-11-19',
#    'state': 'Bihar',
#    'ROC': 'RoC - Patna',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   Vill. Jitjhingoi, Tola Haldimor Panch- Jitjhingoi, Block Khaira JAMUI Jamui BR 811317 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 500000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100BR2018PTC040004',
#    'name': 'KAKAN AGROTECH PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-21',
#    'state': 'Bihar',
#    'ROC': 'RoC - Patna',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   Shital Singh, S/o Fuleshwar Singh Vill- Siyaruwa, Block - Jagdishpur BHOJPUR Bhojpur BR 802158 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 500000,
#    'paidCapital': 200000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100BR2018PTC040081',
#    'name': 'NAGVANSHI BIOTECH PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-28',
#    'state': 'Bihar',
#    'ROC': 'RoC - Patna',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   HOUSE NO 1 BHERIYA DURGAWATI KAIMUR (BHABHUA) BHABHUA Kaimur BR 821105 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 1000000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100CT2018PTC008910',
#    'name': 'BHUIYA MITAN PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-22',
#    'state': 'Chattisgarh',
#    'ROC': 'RoC - Chhattisgarh',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   PROPERTY OF MR. DHANNURAM NAYAK, WARD NO.8, MOHBHATTA, GHOTATOLA, MOHLA Rajnandgaon CT 491666 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 500000,
#    'paidCapital': 500000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100DL2018PLC341854',
#    'name': 'STAR GLOBAL STAR LIMITED',
#    'dateOfIncorporation': '2018-11-15',
#    'state': 'Delhi',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   508-509, D-MALL, NETAJI SUBHASH PLACE PITAMPURA NEW DELHI North West DL 110034 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Public',
#    'authorizedCapital': 1000000,
#    'paidCapital': 154000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100DL2018PTC342105',
#    'name': 'GGV AGRO PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-26',
#    'state': 'Delhi',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   S-70, S BLK, FF, VIJAY VIHAR, UTTAM NAGAR, NR. HOLY PUBLIC SCHOOL, NEW DELHI West Delhi DL 110059 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 500000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100DL2018PTC342218',
#    'name': 'ANNRIC AGRICULTURE INDIA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-27',
#    'state': 'Delhi',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   R-112, 3rd FLOOR, ROOM NO. 402 GALI NO. 6, EAST VINOD NAGAR, DELHI East Delhi DL 110091 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 500000,
#    'paidCapital': 500000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100DL2018PTC342288',
#    'name': 'SPRIHAAT RETAIL NETWORK PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-28',
#    'state': 'Delhi',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   Plot No. 19, Block B, Pocket 4, Sector 23, Dwarka, NEW DELHI New Delhi DL 110075 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 200000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100DL2018PTC342610',
#    'name': 'AADINATHNAKODA INDUSTRIES PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-05',
#    'state': 'Delhi',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   C-5/426 PLOT No. 72 IV/F Milan Vihar TH Indra Prashtha Extn DELHI South Delhi DL 110092 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100GJ2018PTC105158',
#    'name': 'RANCH CROPS INDIA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-13',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   C/O SHANKARBHAI AMBALAL PATEL,MANDIR VALI KHADKI KUNJARAV, VILLAGE : KUNJRAO ANAND Anand GJ 388335 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 200000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100GJ2018PTC105211',
#    'name': 'TORRENTIAL AGRO PRODUCTS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-16',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   104, HAVELI APPARTMENT VARDHMAN NAGAR, KALOL KALOL Ahmedabad GJ 382721 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 10000,
#    'paidCapital': 10000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100GJ2018PTC105218',
#    'name': 'GIRGANGA FARMERS PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-19',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   403/1/1, Kevadra, Pankhan, Village : Pankhan, Taluka : Keshod, PANKHAN Junagadh GJ 362227 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100GJ2018PTC105232',
#    'name': 'JAMNAGAR FARMERS PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-20',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   LS No. 356, Kharivadi, Village : Varna, Taluka : Jamnagar, District : Jamnagar, JAMNAGAR Jamnagar GJ 361130 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100GJ2018PTC105292',
#    'name': 'VALSAD FARMERS PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-26',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   947, Daxin Falia, Gorgam, Village:Gorgam Taluka : Valsad, District : Valsad, GORGAM Valsad GJ 396375 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100GJ2018PTC105294',
#    'name': 'HITARTH AGRITECH PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-26',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   PLOT NO. 16, SURVEY NO. 86, K D SMARK TRUST I.T.C., DIST.: JUNAGADH KADVASAN Junagadh GJ 362725 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100GJ2018PTC105409',
#    'name': 'GUJPAL FARMERS PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-30',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   73, Anand Nagar Soc, NR Jampura, VILL PALANPUR Banas Kantha GJ 385001 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100GJ2018PTC105427',
#    'name': 'WAYNE AGTECH PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-03',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   OFFICE NO 5, SHAILRAJ COMPLEX, MAKARPURA ROAD, VADODARA Vadodara GJ 390014 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 2500000,
#    'paidCapital': 300000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100GJ2018PTC105435',
#    'name': 'SATVABEEJ ORGANIC FOODS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-04',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   36-B KURESHINAGAR CHS, 0633-07-0711-0001 OPP. MAKTAMPURA SCHOOL, SARKHEJ ROAD AHMEDABAD Ahmedabad GJ 382210 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100GJ2018PTC105487',
#    'name': 'KARMAYOG HERBAL PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-06',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   54- FORTUNE IND PARK, KATHWADA, VILL- KATHWADA, TA- DASKROI AHMEDABAD Ahmedabad GJ 382430 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100HR2018PTC076894',
#    'name': 'RAWALWAS PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-14',
#    'state': 'Haryana',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   PLOT NO. 54, NEAR HANUMAN MANDIR VPO - RAWALWAS KHURD HISAR Hissar HR 125001 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 500000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100HR2018PTC077066',
#    'name': 'SURENDERAM AGRO PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-27',
#    'state': 'Haryana',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   30/25, OLD HOODA INDUSTRIAL AREA, GAUSHALA ROAD FATEHABAD Fatehabad HR 125050 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100HR2018PTC077191',
#    'name': 'JAGLAN FARMER PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-12-04',
#    'state': 'Haryana',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   ASHOK RATHI S/O DHARAMBIR 31, GANJBARH PANIPAT Panipat HR 132103 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100HR2018PTC077220',
#    'name': 'FAITHFUL FARMERS PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-12-06',
#    'state': 'Haryana',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   Gurpreet Singh S/o Charan Singh, Green Field Resorts 7km Mile Stone,SikanderPur SIRSA Sirsa HR 125055 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100HR2018PTC077237',
#    'name': 'NARWANA BAGHWANI PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-12-07',
#    'state': 'Haryana',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   C/O RAMBIR S/O GYANI RAM VPO DHARODI, DISTRICT JIND, NARWANA JIND Jind HR 126116 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100HR2018PTC077239',
#    'name': 'BALSAMAND FARMERS PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-12-07',
#    'state': 'Haryana',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   H. NO. 102, BLOCK-5, VILLAGE BALSMAND BALSMAND Hissar HR 125001 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 110000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100HR2018PTC077259',
#    'name': 'KASNI FARMERS PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-12-08',
#    'state': 'Haryana',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   WARD-15,NEAR GOVT. SCHOOL, CHARKI DADRI, BHIWANI Bhiwani HR 127306 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100JH2018PTC012249',
#    'name': 'RUP AGRO GREENERY ORGANIC PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-07',
#    'state': 'Jharkhand',
#    'ROC': 'RoC - Jharkhand',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   C/O SANAT KUMAR MUKHERJEE NEAR ADARSH VIDYA MANDIR SHYAM NAGAR BHULI Dhanbad JH 828104 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 200000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KA2018OPC119090',
#    'name': 'AAKRUTHIS AGROTECH (OPC) PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-03',
#    'state': 'Karnataka',
#    'ROC': 'RoC - Bangalore',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   NO 986, GANSHA KRUPA, SIT EXTENSION, NEAR CAKE PALACE SIT MAIN ROAD TUMAKURU Tumkur KA 572103 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private(One Person Company)',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KA2018PTC118389',
#    'name': 'VIVASV FARMS INDIA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-09',
#    'state': 'Karnataka',
#    'ROC': 'RoC - Bangalore',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   Flat No. 222, Block 4, Sunnyvale Apt, 1st Main, Basavanapura, K R Puram BANGALORE Bangalore KA 560036 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 500000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KA2018PTC118519',
#    'name': 'ALHAMZA FEEDS AND FARMS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-14',
#    'state': 'Karnataka',
#    'ROC': 'RoC - Bangalore',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   #74, AR Complex Mandya Road, Nagamangala MANDYA Mysore KA 571432 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 1000000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KA2018PTC118560',
#    'name': 'CITYFARMERS INDIA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-15',
#    'state': 'Karnataka',
#    'ROC': 'RoC - Bangalore',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   65, 4th Cross, Gaurav Nagar JP Nagar 7th Phase BANGALORE Bangalore KA 560078 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KA2018PTC118581',
#    'name': 'SHRIVAARU FOOD TECH PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-16',
#    'state': 'Karnataka',
#    'ROC': 'RoC - Bangalore',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   # 720, 14th Main Road, M E I layout Bagalagunte, Nagasandra BANGALORE Bangalore KA 560073 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KA2018PTC118913',
#    'name': 'EKAM ULTRA FARMS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-28',
#    'state': 'Karnataka',
#    'ROC': 'RoC - Bangalore',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   #D-3136, Serenita Block, Sobha City, Thanisandra Main Road, BANGALORE Bangalore KA 560077 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KA2018PTC119031',
#    'name': 'SANAMO GREEN CRAFTS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-30',
#    'state': 'Karnataka',
#    'ROC': 'RoC - Bangalore',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   Villa No.07, Apna Sapna Aangan,Rajapura Village Road,Near DLF MyTown Apartment, BANGALORE Bangalore KA 560105 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KA2018PTC119149',
#    'name': 'PENTAGON SEEDS INDIA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-05',
#    'state': 'Karnataka',
#    'ROC': 'RoC - Bangalore',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   No. 240, 1st Main, 7th Cross AMS Layout, Vidyaranyapura BANGALORE Bangalore KA 560097 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KA2018SGC119162',
#    'name': 'KARNATAKA ANTHARAGANGA MICRO IRRIGATION CORPORATION LIMITED',
#    'dateOfIncorporation': '2018-12-05',
#    'state': 'Karnataka',
#    'ROC': 'RoC - Bangalore',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   17, RICHMOND ROAD BANGALORE Bangalore KA 560025 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'State Govt company',
#    'class': 'Public',
#    'authorizedCapital': 50000000,
#    'paidCapital': 500000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KL2018PTC055533',
#    'name': 'PANCHAMALA AGRO & HORTICULTURE FARMERS PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-15',
#    'state': 'Kerala',
#    'ROC': 'RoC - Ernakulam',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   NO VII/214, CHANDRABAVAN PADIMARUD P O ANANDASHRAM KASARGOD Kasargod KL 671531 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KL2018PTC055559',
#    'name': 'NITHYANANDA ORGANIC FARM PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-19',
#    'state': 'Kerala',
#    'ROC': 'RoC - Ernakulam',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   PRANAVAM THIRUVONAPURAM PERAVOOR, MANATHANA Kannur KL 670673 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KL2018PTC055592',
#    'name': 'KALIPPANKULAM EATABLES PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-21',
#    'state': 'Kerala',
#    'ROC': 'RoC - Ernakulam',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   TC 41/1717 (1), Kadiyapattanam MANACAUD P.O Thiruvananthapuram KL 695009 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 760000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100KL2018PTC055817',
#    'name': 'PIRAVI FARMS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-05',
#    'state': 'Kerala',
#    'ROC': 'RoC - Ernakulam',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   Valiamattathil House,TC 30/83-1, KRA 49, R Sugathan Road, ANAYARA P.O Thiruvananthapuram KL 695029 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 1000000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317017',
#    'name': 'GEETAI SOLVENT EXTRACTION PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-13',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   Shop No 61 C Market Yard-Latur LATUR Latur MH 413512 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 10000000,
#    'paidCapital': 1000000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317050',
#    'name': 'BHAURAO AGRO PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-14',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   H.NO.431 DADHEGAON TQ.AMBAD DIST.JALNA DADHEGAON JALNA Jalna MH 431205 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 500000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317053',
#    'name': 'PITHISARIYA AGRO INDUSTRIES PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-14',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   955, DESHPANDE LAYOUT BAGADGANJ NAGPUR Nagpur MH 440008 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 5000000,
#    'paidCapital': 1000000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317061',
#    'name': 'SHIVYOG AGRO INDUSTRIES INDIA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-14',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   SR NO 18039, DWARKADAS COMPLEX, CHUNILAL PETROL PUMP, ADALAT ROAD AURANGABAD Aurangabad MH 431001 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317133',
#    'name': 'IGO FARMER PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-16',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   C/o Shelke Sopan Aparao, A. P. Ashta, Tq. Chakur, Dist. Latur LATUR Latur MH 413513 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 500000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317190',
#    'name': 'WINSAN AGRO PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-19',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   G.NO-2000 PL.NO-2 SINNERKAR TOWN OZER Nashik MH 422206 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 500000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317197',
#    'name': 'VASAVE AGRO INDUSTRIES AND SERVICES PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-19',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   F No 104, Sundaram App.Beh Tal. Dahanu At.Dahanu Road DAHANU Thane MH 401602 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317257',
#    'name': 'GROVEFARMSTEAD PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-20',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   Diazon Engeneering,39, Swastik Ind. Est. Santacruz (East), Agarawal Compound CST ROAD, MUMBAI Mumbai City MH 400055 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317295',
#    'name': 'ETIMAD POULTRY FARMS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-21',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   704, STAR RESIDENCY CHS LTD., OPP.JOGESHWARI STATION, JOGESHWARI MUMBAI Mumbai City MH 400102 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317339',
#    'name': 'SHINDOLKRANTI AGRO PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-22',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   HOUSE NO 354, UBHI GALLI,SHINDOL, VADGAON,TQ. SOYEGAON, AURANGABAD Aurangabad MH 431150 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317595',
#    'name': 'TSORGO ORGANICS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-29',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   PLOT NO 19 NEW DAIMOND NAGAR,KHARBI ROAD NAGPUR Nagpur MH 440009 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 500000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317662',
#    'name': 'MBAGRI GENETIC RESEARCH PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-29',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   C/O BHAGWANDAS BHASNALI NEW MONDHA AMBEJOGAI BEED Bid MH 431517 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317712',
#    'name': 'AHILYABAI HOLKAR FARMERS PRODUCER COMPANY LIMITED',
#    'dateOfIncorporation': '2018-11-30',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   G NO 01 AT DEVGAON TQ KANNAD AURANGABAD Aurangabad MH 431001 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 500000,
#    'paidCapital': 500000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317740',
#    'name': 'GEEKY GRANDPA GARDENING SOLUTIONS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-30',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#    'officeAddressInIndia': '   A - 202, RUPAREL GARDENS, PLOT NO. C/3, SECTOR 23 ,SEAWOODS,NERUL,NAVI MUMBI MUMBAI Thane MH 400706 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U01100MH2018PTC317756',
# ...
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24303TN2018PTC126133',
#    'name': 'DRS GLOBAL GREEN INDIA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-04',
#    'state': 'Tamil Nadu',
#    'ROC': 'RoC - Chennai',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   NO.5/24,2ND STREET NARASINGAPURAM EXTENSION MADUVANKARAI, GUNIDY Chennai TN 600032 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 300000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24303UP2018PTC110992',
#    'name': 'ANICO BIOCARE PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-06',
#    'state': 'Uttar Pradesh',
#    'ROC': 'RoC - Kanpur',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   H NO 3/1143 AMBEDKARPURAM AWAS VIKAS 3 KALYANPUR KANPUR Kanpur UP 208017 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304AP2018PTC109777',
#    'name': 'SIRIS SYNERGY PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-21',
#    'state': 'Andhra Pradesh',
#    'ROC': 'RoC - Hyderabad',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   Suit 101 Plot No16 SriHanumanBrundavanam Behind Subham Convention,RajendraNagar 1 GUNTUR Guntur AP 522006 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 620000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304BR2018PTC040018',
#    'name': 'TARAQQI PHARMACY PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-22',
#    'state': 'Bihar',
#    'ROC': 'RoC - Patna',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   H/O RIZWANA PARWEEN, 1ST FLOOR, NEAR PRAKASH KUNJ, MOH. INDRAPURI COLONY PATNA Patna BR 800014 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304CH2018PTC042262',
#    'name': 'SYNOZEX PHARMA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-16',
#    'state': 'Chandigarh',
#    'ROC': 'RoC - Chandigarh',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   HOUSE NO. 269, SECTOR 25 D, CHANDIGARH Chandigarh CH 160014 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304CH2018PTC042269',
#    'name': 'ZOOFIN PHARMACEUTICALS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-21',
#    'state': 'Chandigarh',
#    'ROC': 'RoC - Chandigarh',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   HOUSE NO 2662, GROUND FLOOR SECTOR 40C, NEAR DPS SCHOOL CHANDIGARH Chandigarh CH 160036 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 500000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304DL2018PTC342309',
#    'name': 'SANCHAY FORMULATIONS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-28',
#    'state': 'Delhi',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   1765 F/F , KUCHA LATTOO SHAH DARIBA KALAN DELHI New Delhi DL 110006 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 300000,
#    'paidCapital': 300000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304DL2018PTC342461',
#    'name': 'VELISOR PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-30',
#    'state': 'Delhi',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   HOUSE NO- 537 FLOOR 1ST, BLOCK- WZ, SIRI NAGAR, SHAKUR BASTI, NEW DELHI New Delhi DL 110034 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304GA2018OPC013796',
#    'name': 'BROWN BRUNEL PHARMACEUTICALS (OPC) PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-29',
#    'state': 'Goa',
#    'ROC': 'RoC - Goa',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   H. NO. 705(1), ST. ANTHONY PRAIS, ANJUNA MAPUSA B ANJUNA North Goa GA 403509 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private(One Person Company)',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304GJ2018PLC105479',
#    'name': 'INOX FLUOROCHEMICALS LIMITED',
#    'dateOfIncorporation': '2018-12-06',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   ABS Towers, 2nd Floor Old Padra Road VADODARA Vadodara GJ 390007 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Public',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304GJ2018PTC105139',
#    'name': 'NISARG INCENSE PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-12',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   13/C, VRUNDAVAN PARK, MADH, NEAR. YOGESHWER DHAM, BHUJ Kachchh GJ 370001 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304GJ2018PTC105227',
#    'name': 'RINBHA PHARMACEUTICALS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-19',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   GF-6, Shree Vishvakarma, Near Jinal Park Jalalpore, NAVSARI Navsari GJ 396421 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304GJ2018PTC105489',
#    'name': 'PHYTO CONCENTRATES PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-06',
#    'state': 'Gujarat',
#    'ROC': 'RoC - Ahmedabad',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   A/901, Sundarvan Epitome, B/h Sundarvan, Nr. Red Briks School, Jodhpur, AHMEDABAD Ahmedabad GJ 380015 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304HR2018PTC077221',
#    'name': 'CAZIMEHAK PHARMA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-06',
#    'state': 'Haryana',
#    'ROC': 'RoC - Delhi',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   C/O JOGINDER,NEAR ANAJ MANDI GATE TOHANA ROAD,BHUNA BHUNA Fatehabad HR 125111 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304KA2018PTC118418',
#    'name': 'FLOWCHEM PHARMA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-12',
#    'state': 'Karnataka',
#    'ROC': 'RoC - Bangalore',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   40 VARSHINI 2ND MAIN KALYANNAGAR NAGARBAVI MAIN ROAD BANGALORE Bangalore KA 560072 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 50000000,
#    'paidCapital': 1000000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304KL2018PTC055650',
#    'name': 'SIFETSHABOON BEAUTY CARE PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-26',
#    'state': 'Kerala',
#    'ROC': 'RoC - Ernakulam',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   Building No.7/655, Near SNGS College, MELE PATTAMBI Palakkad KL 679306 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 1000000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304MH2018PTC317104',
#    'name': 'SKYE PAINT INDUSTRIES PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-15',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   Unit No. 111,112 & 113 First Floor, Building No E10, Parasnath Complex OVALI VILLAGE BHIWANDI Thane MH 421302 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304MH2018PTC317356',
#    'name': 'NUVAE HEALTHCARE PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-22',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   204, 2ND FLOOR, MANEK SMRUTI, ABOVE HDFC BANK NEHRU RD, VILEPARLE EAST MUMBAI Mumbai City MH 400057 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304MH2018PTC317487',
#    'name': 'CLIMATE AGROBOTIX INDIA PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-11-27',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   Flat 103, Sathyam Building Plot A51-53; A63 & A64, Sector 20, Nerul NAVI MUMBAI Thane MH 400706 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304MH2018PTC317900',
#    'name': 'KASRIDAN ESSENTIALS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-06',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   85 Atkar Lay-out Umred Road NAGPUR Nagpur MH 440024 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  {'entity': {'isCompany': True,
#    'isLLP': False,
#    'isForeign': False,
#    'isDomestic': True,
#    'identityLabel': 'CIN',
#    'type': 'incorporation',
#    'identityNumber': 'U24304MH2018PTC317902',
#    'name': 'NIYAMA PHARMACEUTICALS PRIVATE LIMITED',
#    'dateOfIncorporation': '2018-12-06',
#    'state': 'Maharashtra',
#    'ROC': 'RoC - Mumbai',
#    'activityDiscription': 'Manufacture of chemicals and chemical products',
#    'officeAddressInIndia': '   FLAT C-1202, THARWANI RESIDENCY, MIDC PLOT C 1, SECTOR 6 A,KAMOTHE PANVEL NAVI MUMBAI Raigarh MH 410206 IN'},
#   'incorporationData': {'category': 'Company limited by Shares',
#    'subCategory': 'Non-govt company',
#    'class': 'Private',
#    'authorizedCapital': 100000,
#    'paidCapital': 100000},
#   'registrationData': 'null'},
#  ...]

# %%
mongoClient=MongoClient()
db=mongoClient.mcaGovIn
collection=db.companies

# %%
collection.drop()
collection.insert_many(dataList)

# %%
isCompany: True / False
isLLP: True / False
isForeign: True / False
isDomestic: True / False

# %%
"backup file*************************************************************************************"

# -*- coding: utf-8 -*-
import scrapy
import pandas as pd
import sys
import os
import seaborn as sns
import matplotlib.pyplot as plt
from pymongo import MongoClient
import json
import datetime
import numpy as np

class MyspiderbotSpider(scrapy.Spider):
        
    name = 'mySpiderBot'
    allowed_domains = ['http://mca.gov.in']
    start_urls = ['http://mca.gov.in/mcafoportal/companiesRegReport.do']
    errorFileName="error.log"
    dataFileName="Company_Registered_in_Last_30days_"+datetime.datetime.now().strftime("%d_%m_%h")+".xlsx"
    dataFileLocation="/home/digiapt/Desktop/mca_gov_in/mca_gov_in/spiders/fetchedFile/"+dataFileName
    successFileName="success.log"
    
    schemaColumns={
        "COMPANY NAME":"name",
        "LIMITED LIABILITY PARTNERSHIP NAME":"name",
        "FOREIGN LIMITED LIABILITY PARTNERSHIP":"name",
        "CIN":"identityNumber",
        "FCRN":"identityNumber",
        "LLPIN":"identityNumber",
        "FLLPIN":"identityNumber",
        "COUNTRY":"country",
        "COUNTRY OF INCORPORATION":"country",
        "DATE OF INCORPORATION":"dateOfIncorporation",
        "DATE OF REGISTRATION":"dateOfIncorporation",
        "STATE":"state",
        "STATE OF PRINCIPAL PLACE OF BUSINESS IN INDIA":"state",
        "ROC":"ROC",
        "CATEGORY":"category",
        "SUB CATEGORY":"subCategory",
        "CLASS":"class",
        "AUTHORIZED_CAPITAL":"authorizedCapital",
        "PAID CAPITAL":"paidCapital",
        "NUMBER OF PARTNERS":"numberOfPartners",
        "NUMBER OF MEMBERS (Applicable only in case of Co. without share Capital)":"numberOfPartners",
        "NUMBER OF DESIGNATED PARTNERS":"numberOfDesignatedParters",
        "ACTIVITY DESCRIPTION":"activityDiscription",
        "ACTIVITY_DESCRIPTION":"activityDiscription",
        "REGISTERED_OFFICE_ADDRESS":"officeAddressInIndia",
        "FOREIGN COMPANY PRESENT ADDRESS IN INDIA":"officeAddressInIndia",
        "FOREIGN OFFICE ADDRESS":"officeAddressInForeign",
        "TOTAL OBLIGATION OF CONTRIBUTION":"totalObligationOfContribution",
        "TYPE OF OFFICE":"typeOfOffice"}
    schema2sheet={
        "name":0,
        "identityNumber" :0,
        "country":0,
        "dateOfIncorporation":0,
        "state":0,
        "ROC":0,
        "category":0,
        "subCategory":0,
        "class":0,
        "authorizedCapital":0,
        "paidCapital":0,
        "numberOfPartners":0,
        "numberOfDesignatedParters":0,
        "activityDiscription":0,
        "officeAddressInIndia":0,
        "officeAddressInForeign":0,
        "totalObligationOfContribution":0,
        "typeOfOffice":0
        }

    def createDataList(self,df,sheet,dataList,sheetOne,sheetTwo,sheetThree,sheetFour):
        if sheet==sheetOne: #"Indian Companies Registered"
            columns=df.columns.values
            commonCol={}
            for col in columns:
                    commonCol[self.schemaColumns[col]]=0
            for index in range(df.shape[0]):
                tmp={}
                tmp['isCompany']=True;tmp['isLLP']=False;tmp['vehicle']="company";tmp['isForeign']=False;tmp['isDomestic']=True;tmp['identityLabel']="CIN"
                row=df.iloc[index]
                for col in columns:
                    tmp[self.schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                for unInsertedKey in self.schema2sheet.keys():
                    if unInsertedKey not in commonCol:
                        tmp[unInsertedKey]="null"
                dataList.append(tmp)
        
        elif sheet==sheetTwo: #Foreign Companies Registered
            columns=df.columns.values
            commonCol={}
            for col in columns:
                    commonCol[self.schemaColumns[col]]=0
            for index in range(df.shape[0]):
                tmp={}
                tmp['isCompany']=True;tmp['isLLP']=False;tmp['vehicle']="company";tmp['isForeign']=True;tmp['isDomestic']=False;tmp['identityLabel']="FCRN"
                row=df.iloc[index]
                for col in columns:
                    tmp[self.schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                for unInsertedKey in self.schema2sheet.keys():
                    if unInsertedKey not in commonCol:
                        tmp[unInsertedKey]="null"
                dataList.append(tmp)
            
        elif sheet==sheetThree: #LLP Registered
            columns=df.columns.values
            commonCol={}
            for col in columns:
                    commonCol[self.schemaColumns[col]]=0
            for index in range(df.shape[0]):
                tmp={}
                tmp['isCompany']=False;tmp['isLLP']=True;tmp['vehicle']="LLP";tmp['isForeign']=False;tmp['isDomestic']=True;tmp['identityLabel']="LLPIN"
                row=df.iloc[index]
                for col in columns:
                    tmp[self.schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                for unInsertedKey in self.schema2sheet.keys():
                    if unInsertedKey not in commonCol:
                        tmp[unInsertedKey]="null"
                dataList.append(tmp)        
        
        elif sheet==sheetFour: #Foreign LLP Registered
            columns=df.columns.values
            commonCol={}
            for col in columns:
                    commonCol[self.schemaColumns[col]]=0
            for index in range(df.shape[0]):
                tmp={}
                tmp['isCompany']=False;tmp['isLLP']=True;tmp['LLP']="company";tmp['isForeign']=True;tmp['isDomestic']=False;tmp['identityLabel']="FLLPIN"
                try:
                    row=df.iloc[index]
                    for col in columns:
                        tmp[self.schemaColumns[col]]=row[col] if row[col] is not pd.np.nan else "null"
                    for unInsertedKey in self.schema2sheet.keys():
                        if unInsertedKey not in commonCol:
                            tmp[unInsertedKey]="null"
                    dataList.append(tmp)
                except Exception as e:
                    pass
        return dataList
    
    
    
    
    def readAndInsert(self,fileLocation):
        excelFile=pd.ExcelFile(fileLocation)

    def errorback(self,res):
        with open(self.errorFileName,"a") as fp:
            fp.write(datetime.datetime.now().strftime("%d-%m-%h (%H:%M:%S)")+" - "+str(res)+"\r\n")
        print("please check error log file for more information")
        
    def callback(self,res):
        content=res.body
        with open(self.dataFileLocation,"wb") as fp:
            fp.write(content)
        print("done writing")
        dataList=[]
        excelFile=pd.ExcelFile(self.dataFileLocation)
        sheetOne="Indian Companies Registered"
        sheetTwo="Foreign Companies Registered"
        sheetThree="LLP Registered"
        sheetFour="Foreign LLP Registered"
        for sheet in excelFile.sheet_names:
            df=pd.read_excel(excelFile,sheet_name=sheet)
            df.columns=df.iloc[0]
            df.drop(0,inplace=True)
            dataList=self.createDataList(df,sheet,dataList,sheetOne,sheetTwo,sheetThree,sheetFour)
        meta={}
        meta["dateCreated"]=datetime.datetime.now().strftime("%d/%m/%y")
        meta["source"]="http://mca.gov.in"
        meta["sourceURL"]="http://mca.gov.in/mcafoportal/companiesRegReport.do"
        dataList.append({"metaData":meta})
        mongoClient=MongoClient()
        db=mongoClient.mcaGovIn
        collection=db.companies
        try:
            collection.insert_many(dataList)
            with open(self.successFileName,"a") as fp:
                fp.write(datetime.datetime.now().strftime("%d-%m-%h (%H:%M:%S)")+" - "+" Insertion Successful, Successfully Crawled"+"\r\n")
            print("**********************************Successfully Crawled*******************************************")
        except Exception as e:
            with open(self.errorFileName,"a") as fp:
                fp.write(datetime.datetime.now().strftime("%d-%m-%h (%H:%M:%S)")+" - "+" Insertion Failed: - "+str(e)+"\r\n")
            print("**********************************Insertion Failed, Please check error log for more information*******************************************")
        




    def start_requests(self):
        headers= {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:63.0) Gecko/20100101 Firefox/63.0','Cache-Control': 'max-age=0','referer':'mca.gov.in'}
        for url in self.start_urls:
            yield scrapy.Request(url,headers=headers,errback=self.errorback,callback=self.callback,dont_filter=True)

# %%
dataList
# Out:
# [{'isCompany': True,
#   'isLLP': False,
#   'isForeign': False,
#   'isDomestic': True,
#   'identityLabel': 'CIN',
#   'identityNumber': 'U01100AP2018PTC109756',
#   'name': 'BUBBA AQUA FARM TECH PRIVATE LIMITED',
#   'dateOfIncorporation': '2018-11-16',
#   'state': 'Andhra Pradesh',
#   'ROC': 'RoC - Hyderabad',
#   'category': 'Company limited by Shares',
#   'subCategory': 'Non-govt company',
#   'class': 'Private',
#   'authorizedCapital': 100000,
#   'paidCapital': 100000,
#   'numberOfPartners': '0',
#   'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#   'officeAddressInIndia': '   10-2, OLD ANDHRA BANK ROAD, D2 CHIRALA CHIRALA Prakasam AP 523165 IN',
#   'country': 'null',
#   'numberOfDesignatedParters': 'null',
#   'officeAddressInForeign': 'null',
#   'totalObligationOfContribution': 'null',
#   'typeOfOffice': 'null'},
#  {'isCompany': True,
#   'isLLP': False,
#   'isForeign': False,
#   'isDomestic': True,
#   'identityLabel': 'CIN',
#   'identityNumber': 'U01100AP2018PTC109775',
#   'name': 'CLARION HEIGHTS INDIA PRIVATE LIMITED',
#   'dateOfIncorporation': '2018-11-20',
#   'state': 'Andhra Pradesh',
#   'ROC': 'RoC - Hyderabad',
#   'category': 'Company limited by Shares',
#   'subCategory': 'Non-govt company',
#   'class': 'Private',
#   'authorizedCapital': 100000,
#   'paidCapital': 100000,
#   'numberOfPartners': '0',
#   'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#   'officeAddressInIndia': '   D.NO.1-164, BRAHMIN STREET, DACHEPALLI VILLAGE, GUNTUR Guntur AP 522414 IN',
#   'country': 'null',
#   'numberOfDesignatedParters': 'null',
#   'officeAddressInForeign': 'null',
#   'totalObligationOfContribution': 'null',
#   'typeOfOffice': 'null'},
#  {'isCompany': True,
#   'isLLP': False,
#   'isForeign': False,
#   'isDomestic': True,
#   'identityLabel': 'CIN',
#   'identityNumber': 'U01100AP2018PTC109823',
#   'name': 'VANAPAMULA SEEDS PRIVATE LIMITED',
#   'dateOfIncorporation': '2018-11-28',
#   'state': 'Andhra Pradesh',
#   'ROC': 'RoC - Hyderabad',
#   'category': 'Company limited by Shares',
#   'subCategory': 'Non-govt company',
#   'class': 'Private',
#   'authorizedCapital': 1000000,
#   'paidCapital': 200000,
#   'numberOfPartners': '0',
#   'activityDiscription': 'Activities Agriculture, Hunting and related Service activities',
#   'officeAddressInIndia': '   D.No.2-2-80, Flat No. 301, 3rd Floor, Tulasi Nilayam,UdyogNagar,SVN Colony ext GUNTUR Guntur AP 522006 IN',
#   'country': 'null',
#   'numberOfDesignatedParters': 'null',
#   'officeAddressInForeign': 'null',
#   'totalObligationOfContribution': 'null',
#   'typeOfOffice': 'null'}]

# %%
'COMPANY NAME' in schemaColumns
# Out:
# True

# %%
df.iloc[0]["DATE OF INCORPORATION"]
# Out:
# '2018-11-16'

# %%
import scrapy
import pandas as pd
import sys
import os
import seaborn as sns
import matplotlib.pyplot as plt
from pymongo import MongoClient
import json
#domains_='http://mca.gov.in/mcafoportal/companiesRegReport.do'
#start_urls='http://mca.gov.in/mcafoportal/companiesRegReport.do'
fileName="tmp.xlsx"
fileLocation="/home/digiapt/anaconda3/bin/webCrawler/mySpider/mySpider/spiders/"+fileName
class ScrapyspiderSpider(scrapy.Spider):
    #global domains_,start_urls
    name='scrapySpider'
    allowed_domains = ['http://www.mca.gov.in']
    start_urls = ['http://mca.gov.in/mcafoportal/companiesRegReport.do']
    def errorFun(self,response):
        print("***************Please Check Your Internet Connection*******************")
    lastRow={}
    def callFun(self,response):
        scraped_info= response.body
        with open(fileLocation, 'wb') as f:
            f.write(scraped_info)
            f.flush()


        xls=pd.ExcelFile("./"+fileName)
        dataList=[]
        #{fileName:{last row of each datasheet}}
        lastRow={}
        jsonString=None
        with open("./lastRow.json",'r') as fp:
            jsonString=json.loads(fp.readlines()[0])
        for sheet in xls.sheet_names:
            df=pd.read_excel(xls,sheet_name=sheet)
            df.columns=df.iloc[0].values
            df.drop(0,inplace=True)
            if jsonString:
                lastRowJson=jsonString[sheet]
                if sheet=="LLP Registered":
                    try:
                        newDf=df[df.index[(df["LIMITED LIABILITY PARTNERSHIP NAME"]==lastRowJson["LIMITED LIABILITY PARTNERSHIP NAME"])&(df["LLPIN"]==lastRowJson["LLPIN"])].tolist()[0]:]
                        dataList.append({sheet:self.df2dict(newDf,sheet)})
                    except Exception as e:
                        pass
                elif sheet=="Foreign Companies Registered":
                    try:
                        newDf=df[df.index[(df["COMPANY NAME"]==lastRowJson["COMPANY NAME"])&(df["FCRN"]==lastRowJson["FCRN"])].tolist()[0]:]
                        dataList.append({sheet:self.df2dict(newDf,sheet)})
                    except Exception as e:
                        pass
                elif sheet=="Foreign LLP Registered":
                    try:
                        newDf=df[df.index[(df["FLLPIN"]==lastRowJson["FLLPIN"])&(df["FOREIGN LIMITED LIABILITY PARTNERSHIP"]==lastRowJson["FOREIGN LIMITED LIABILITY PARTNERSHIP"])].tolist()[0]:]
                        dataList.append({sheet:self.df2dict(newDf,sheet)})
                    except Exception as e:
                        pass
                elif sheet=="Indian Companies Registered":
                    try:
                        newDf=df[df.index[(df["COMPANY NAME"]==lastRowJson["COMPANY NAME"])&(df["CIN"]==lastRowJson["CIN"])].tolist()[0]:]
                        dataList.append({sheet:self.df2dict(newDf,sheet)})
                    except Exception as e:
                    pass                
            lastRow[sheet]=self.df2dict(df.tail(1),sheet)[0]

        '''
        df=pd.read_excel("./record.xlsx")
        df.columns=df.iloc[0].values
        df.drop(0,inplace=True)
        df.to_csv("record.csv",index=False)
        dfCsv=pd.read_csv("record.csv")
        fig= plt.figure(1, [20, 8])
        ax = fig.add_subplot(1, 1, 1) 
        ax.set_xlim(-1,100)
        plt.setp(ax.get_xticklabels(), fontsize=10, rotation='70')
        snsPlot=sns.countplot(df.STATE)
        snsPlot.figure.savefig("countPlot.jpg")
        '''
        

        client=MongoClient()
        db=client.Company_Registered_in_Last_30days
        collection=db.companies
        collection.insert_many(dataList)
        client.close()

        #with open("./lastRow.json",'w') as fp:
            #json.dump(lastRow,fp)
        #if os.path.exists("fileName"):
            #os.remove("filename")
        


        yield {"********************Crawling Finished********************":0}
    def start_requests(self):
        headers= {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:63.0) Gecko/20100101 Firefox/63.0','Cache-Control': 'max-age=0','referer':'mca.gov.in'}
        for url in self.start_urls:
            yield scrapy.Request(url, headers=headers,errback=self.errorFun,callback=self.callFun,dont_filter=True)
    def df2dict(self,df,sheet):
        dataList=[]
        columns=df.columns
        for index in range(df.shape[0]):
            tmp={}
            for col in columns:
                if str(col).replace('.',' ').strip()=="DATE OF INCORPORATION":
                    parsed=str(df.iloc[index][col]).replace('.',' ').strip().split("-")
                    tmp[str(col).replace('.',' ').strip()]={"year":parsed[0],"month":parsed[1],"day":parsed[-1]}
                elif str(col).replace('.',' ').strip()=="REGISTERED_OFFICE_ADDRESS":
                    if sheet.strip()== "Indian Companies Registered":
                        parsed=str(df.iloc[index][col]).replace('.',' ').strip().rsplit(" ",2)
                        tmp[str(col).replace('.',' ').strip()]={"address":(parsed[0]+" "+parsed[-1]),"zipCode":parsed[-2]}
                    else:
                        parsed=str(df.iloc[index][col]).replace('.',' ').strip().rsplit(" ",1)
                        tmp[str(col).replace('.',' ').strip()]={"address":parsed[0],"zipCode":parsed[-1]}
                else:tmp[str(col).replace('.',' ').strip()]=str(df.iloc[index][col]).replace('.',' ')
            dataList.append(tmp)
        return dataList
# Out:
#   File "<ipython-input-53-2ade6452478d>", line 64
#     pass
#        ^
# IndentationError: expected an indented block

# %%
# -*- coding: utf-8 -*-
import scrapy
import os
import datetime
dataFilename="Company_Registered_in_Last_30days_"+datetime.datetime.now().strftime("%d_%m_%h")
dataFileLocation="/home/digiapt/anaconda3/bin/webCrawler/mySpider/mySpider/spiders/"+fileName
class MyspiderbotSpider(scrapy.Spider):
    name = 'mySpiderBot'
    allowed_domains = ['http://mca.gov.in']
    start_urls = ['http://http://mca.gov.in/']
    errorFileName="error.log"
    def errorback(self,res):
        with open(errorFileName,"a") as fp:
            fp.write(datetime.datetime.now().strftime("%d-%m-%h (%H:%M:%S)"),"-",res,"\r\n")
        print("please check error log file for more information")
    def callback(self,res):
        content=res.body
        with open(dataFileLocation+dataFileName) as fp:
            fp.write(content,"w")
        print("done writing")
        
            
    
    def start_requests(self):
        headers= {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:63.0) Gecko/20100101 Firefox/63.0','Cache-Control': 'max-age=0','referer':'mca.gov.in'}
        for url in self.start_urls:
            yield scrapy.Request(url,headers=headers,errback=self.errorback,callback=self.callback,dont_filter=True)

# %%
json.loads(json.dumps({"1":12}))
# Out:
# {'1': 12}
